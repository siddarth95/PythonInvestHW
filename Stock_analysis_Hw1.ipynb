# %% [markdown]
# <a href="https://colab.research.google.com/github/siddarth95/PythonInvestHW/blob/main/Stock_analysis_Hw1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTS
import numpy as np
import pandas as pd

#Fin Data Sources
import yfinance as yf
import pandas_datareader as pdr

#Data viz
import plotly.graph_objs as go
import plotly.express as px

import time
from datetime import date

# %% [markdown]
# Question 1: [Macro] Average growth of GDP in 2023
#
# What is the average growth (in %) of GDP in 2023?
#
# Download the timeseries Real Gross Domestic Product (GDPC1) from FRED (https://fred.stlouisfed.org/series/GDPC1). Calculate year-over-year (YoY) growth rate (that is, divide current value to one 4 quarters ago). Find the average YoY growth in 2023 (average from 4 YoY numbers). Round to 1 digit after the decimal point: e.g. if you get 5.66% growth => you should answer 5.7

# %%
# Real Potential Gross Domestic Product (GDPPOT), Billions of Chained 2012 Dollars, QUARTERLY
# https://fred.stlouisfed.org/series/GDPC1
gdpc1 = pdr.DataReader("GDPC1", "fred", start='1990')

gdpc1['gdpC1_us_yoy'] = gdpc1.GDPC1/gdpc1.GDPC1.shift(4)-1
gdpc1['gdpC1_us_qoq'] = gdpc1.GDPC1/gdpc1.GDPC1.shift(4)-1
gdpc1.tail()
# Out:
#                 GDPC1  gdpC1_us_yoy  gdpC1_us_qoq
# DATE
# 2022-10-01  21989.981      0.006517      0.006517
# 2023-01-01  22112.329      0.017179      0.017179
# 2023-04-01  22225.350      0.023825      0.023825
# 2023-07-01  22490.692      0.029269      0.029269
# 2023-10-01  22679.255      0.031345      0.031345

# %%
gdpc2023 = gdpc1.loc[gdpc1.index > '2022-10-01']
print(gdpc2023.head())
gdpc2023['gdpC1_us_yoy'].mean()
# Out:
#                 GDPC1  gdpC1_us_yoy  gdpC1_us_qoq
# DATE
# 2023-01-01  22112.329      0.017179      0.017179
# 2023-04-01  22225.350      0.023825      0.023825
# 2023-07-01  22490.692      0.029269      0.029269
# 2023-10-01  22679.255      0.031345      0.031345
# 0.02540443392867625

# %% [markdown]
# Question 2. [Macro] Inverse "Treasury Yield"
#
# Find the min value of (dgs10-dgs2) after since year 2000 (2000-01-01) and write it down as an answer, round to 1 digit after the decimal point.
#
# Download DGS2 and DGS10 interest rates series (https://fred.stlouisfed.org/series/DGS2, https://fred.stlouisfed.org/series/DGS10). Join them together to one dataframe on date (you might need to read about pandas.DataFrame.join()), calculate the difference dgs10-dgs2 daily.
#
# (Additional: think about what does the "inverted yield curve" mean for the market and investors? do you see the same thing in your country/market of interest? Do you think it can be a good predictive feature for the models?)

# %%
start_tmp = '2000-01-01'

dgs2 = pdr.DataReader("DGS2", "fred", start=start_tmp)
dgs10 = pdr.DataReader("DGS10", "fred", start=start_tmp)

dgs2.head()
# Out:
#             DGS2
# DATE
# 2000-01-03  6.38
# 2000-01-04  6.30
# 2000-01-05  6.38
# 2000-01-06  6.35
# 2000-01-07  6.31

# %%
merged_df = dgs2.join(dgs10)
merged_df['Diff'] = merged_df['DGS10']-merged_df['DGS2']
merged_df['Diff'].min()
# Out:
# -1.0800000000000005

# %%
import yfinance as yf

# download dataframe
spx = yf.download("^GSPC", start="2019-04-09", end="2024-04-09")
mxx = yf.download("^MXX", start="2019-04-09", end="2024-04-09")
# spx = pdr.get_data_stooq('^SPX', '2019-04-09', '2024-04-09')
# mxx = pdr.get_data_stooq('^MXX', '2019-04-09', '2024-04-09')
mxx.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2019-04-09  45346.828125  45346.828125  44854.531250  45151.628906
# 2019-04-10  45204.750000  45219.410156  44850.109375  44909.140625
# 2019-04-11  44872.531250  44966.500000  44373.488281  44580.058594
# 2019-04-12  44767.671875  44888.699219  44534.378906  44686.058594
# 2019-04-15  44649.738281  44900.929688  44347.531250  44625.781250
#
#                Adj Close     Volume
# Date
# 2019-04-09  45151.628906  191575000
# 2019-04-10  44909.140625  145314900
# 2019-04-11  44580.058594  109090000
# 2019-04-12  44686.058594  143662400
# 2019-04-15  44625.781250  108627100

# %%
spx_return = spx['Adj Close'][-1]/spx['Adj Close'][0] - 1
print(spx_return)

mxx_return = mxx['Adj Close'][-1]/mxx['Adj Close'][0] - 1
print(mxx_return)
# Out:
# 0.8075151917783085
# 0.2843377484045295

# %%
stock_list = ['2222.SR','BRK-B','AAPL','MSFT','GOOG','JPM']
last_price = []
for ticker in stock_list:
  print(ticker)
  prices = yf.download(ticker,start='2023-01-01',end='2023-12-31')
  max_price = prices['Adj Close'].max()
  min_price = prices['Adj Close'].min()
  print((max_price-min_price)/max_price)
  last_price.append(prices['Adj Close'][-1])

last_price
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# 2222.SR
# 0.21393070882746015
# BRK-B
# 0.20775750091289963
# AAPL
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# 0.37244419224463476
# MSFT
# 0.4242066515530231
# GOOG
# 0.3924520921912013
# JPM
# [*********************100%%**********************]  1 of 1 completed
# 0.28249927707093897
# [32.87778854370117,
#  356.6600036621094,
#  192.28463745117188,
#  375.34588623046875,
#  140.92999267578125,
#  168.07711791992188]

# %%
for i in range(len(stock_list)):
  print(stock_list[i])
  msft = yf.Ticker(stock_list[i])
  d = msft.dividends
  f = d.loc[d.index>'2023']
  h = f.loc[f.index<'2024']

  print(h.sum()/last_price[i])
# Out:
# 2222.SR
# 0.027701498195032558
# BRK-B
# 0.0
# AAPL
# 0.004940592304162832
# MSFT
# 0.007433143940964608
# GOOG
# 0.0
# JPM
# 0.02409608190645897

# %%
ticker = yf.Ticker('AAPL').info
ticker
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '408 996 1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...
